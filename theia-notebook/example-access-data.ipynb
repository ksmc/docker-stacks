# %%
### CSV file URL i.e. copa-cases-by-complainant-or-subject.csv
data_file_url='https://mphdatastaging.blob.core.windows.net/d1-t1/copa-cases-by-complainant-or-subject.csv?st=2019-09-20T15%3A54%3A01Z&se=2019-11-21T15%3A54%3A00Z&sp=rl&sv=2018-03-28&sr=c&sig=FAbpfU0UQ82yPkYCYL6vxlsJbnLQAl%2FmU6eP4zfjNVE%3D'

# %%
# Use Pandas
import pandas as pd
df = pd.read_csv(data_file_url)
df.head(10)
# Out:
#     LOG_NO           COMPLAINT_DATE ASSIGNMENT  CASE_TYPE  \
# 0  1092329  2019-01-12T10:44:54.000        BIA        NaN
# 1  1092328  2019-01-12T10:24:30.000        BIA        NaN
# 2  1092327  2019-01-11T22:30:46.000        BIA        NaN
# 3  1092326  2019-01-11T15:29:31.000        BIA        NaN
# 4  1092325  2019-01-11T15:18:16.000       COPA  Complaint
# 5  1092325  2019-01-11T15:18:16.000       COPA  Complaint
# 6  1092324  2019-01-11T14:48:54.000        BIA        NaN
# 7  1092323  2019-01-11T14:10:36.000        BIA        NaN
# 8  1092322  2019-01-11T14:06:40.000        BIA        NaN
# 9  1092320  2019-01-11T13:37:44.000        BIA        NaN
#
#           CURRENT_STATUS CURRENT_CATEGORY FINDING_CODE POLICE_SHOOTING  BEAT  \
# 0                    NaN              NaN          NaN             NaN   NaN
# 1                    NaN              NaN          NaN             NaN   NaN
# 2                    NaN              NaN          NaN             NaN   NaN
# ...

# %%
# Use Requests package
import requests
r = requests.get(data_file_url)
# Save file to local folder
file_name = 'copa-cases-by-complainant-or-subject.csv'
home_dir = '/home/jovyan'
path_to_file = '/{}'.format(file_name)
file_size = open(home_dir+path_to_file, 'wb').write(r.content)

# %%
# Json & GEOJson, i.e. gz_2010_us_050_00_20m.json
data_file_url = 'https://mphdatastaging.blob.core.windows.net/d1-t1/gz_2010_us_050_00_20m.json?st=2019-09-20T15%3A54%3A01Z&se=2019-11-21T15%3A54%3A00Z&sp=rl&sv=2018-03-28&sr=c&sig=FAbpfU0UQ82yPkYCYL6vxlsJbnLQAl%2FmU6eP4zfjNVE%3D'
import requests
r = requests.get(data_file_url)
gz_2010_us = r.json()
